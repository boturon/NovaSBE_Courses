# %%
from sklearn.decomposition import PCA
import pandas as pd
import os

# %%
path = "./data/tables-of-EU-policy/"
files = os.listdir(path+"converted/")

# %% [markdown]
# ## **tips** Macroeconomic imbalance procedure indicators
# - **tips_h** - MIP Scoreboard indicators
# - **tipsbp** - Current account balance and balance of payments
# - **tipsii** - International investment position
# - **tipsed** - External debt
# - **tipser** - Effective exchange rates
# - **tipsex** - Export market shares
# - **tipsgo** - General government gross debt (EDP concept)
# - **tipsfs** - Financial sector liabilities
# - **tipspd** - Private sector debt
# - **tipspc** - Private sector credit flow
# - **tipsnf** - Non-financial transactions - annual data
# - **tipsun** - Unemployment
# - **tipslc** - Unit labour cost
# - **tipsho** - House price indices
# - **tipspo** - Poverty and social exclusion
# - **tipsgd** - Gross domestic product (GDP)
# - **tipsrd** - Research and development
# - **mips_sa** - Macroeconomic imbalance procedure - Statistical annex indicators

# %%
tips = ["tips_h", "tipsbp", "tipsii", "tipsed", "tipser", "tipsex", "tipsgo", "tipsfs", "tipspd", "tipspc", "tipsnf", "tipsun", "tipslc", "tipsho", "tipspo", "tipsgd", "tipsrd", "mips_sa"]

# %% [markdown]
# - *tipsbp10* - Current account balance - 3 year average (tipsbp10)
# - *tipsii10* - Net international investment position - annual data (tipsii10)
# - *tipser10* - Real effective exchange rate (42 trading partners, based on HICP/CPI) (tipser10)
# - *tipsex10* - Export market shares - 5 years % change (tipsex10)
# - *tipslm10* - Nominal unit labour cost - 3 years % change (tipslm10)
# - *tipsho10* - House price index, deflated - annual data (tipsho10)
# - *tipspc20* - Private sector credit flow, consolidated - % GDP (tipspc20)
# - *tipspd20* - Private sector debt, consolidated - % of GDP (tipspd20)
# - *tipsgo10* - General government gross debt (EDP concept), consolidated - annual data (tipsgo10)
# - *tipsun10* - Unemployment rate - 3 year average (tipsun10)
# - *tipsfs10* - Total financial sector liabilities, non-consolidated - annual data (tipsfs10)
# - *tipslm60* - Activity rate - % of total population aged 15-64 (tipslm60)
# - *tipslm70* - Long-term unemployment rate, % of active population aged 15-74 (tipslm70)
# - *tipslm80* - Youth unemployment rate - % of active population aged 15-24 (tipslm80)

# %%
tips_h = ["tipsbp10", "tipsii10", "tipser10", "tipsex10", "tipslm10", "tipsho10", "tipspc20", "tipspd20", "tipsgo10", "tipsun10", "tipsfs10", "tipslm60", "tipslm70", "tipslm80"]

# %%
pd.read_csv(path+"converted/"+tips_h[0]+".csv")
# Out:
#           unit s_adj bop_item stk_flow   partner geotime        date  value
# 0    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  1995-01-01    NaN
# 1    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  1996-01-01    NaN
# 2    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  1997-01-01    2.0
# 3    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  1998-01-01    2.0
# 4    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  1999-01-01    2.0
# 5    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2000-01-01    1.0
# 6    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2001-01-01    1.0
# 7    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2002-01-01    0.0
# 8    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2003-01-01    1.0
# 9    PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2004-01-01    1.0
# 10   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2005-01-01    2.0
# 11   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2006-01-01    2.0
# 12   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2007-01-01    NaN
# 13   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2008-01-01    NaN
# 14   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2009-01-01    NaN
# 15   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2010-01-01    NaN
# 16   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2011-01-01    NaN
# 17   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2012-01-01    NaN
# 18   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2013-01-01    NaN
# 19   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2014-01-01    NaN
# 20   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2015-01-01    NaN
# 21   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2016-01-01    NaN
# 22   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      AT  2017-01-01    NaN
# 23   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  1995-01-01    NaN
# 24   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  1996-01-01    NaN
# 25   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  1997-01-01    NaN
# 26   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  1998-01-01    NaN
# 27   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  1999-01-01    NaN
# 28   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  2000-01-01    NaN
# 29   PC_GDP_3Y   NSA       CA      BAL  WRL_REST      BE  2001-01-01    NaN
# ..         ...   ...      ...      ...       ...     ...         ...    ...
# 614  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2011-01-01    NaN
# 615  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2012-01-01    NaN
# 616  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2013-01-01    NaN
# 617  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2014-01-01    NaN
# 618  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2015-01-01    NaN
# 619  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2016-01-01    NaN
# 620  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      SK  2017-01-01    NaN
# 621  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  1995-01-01    NaN
# 622  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  1996-01-01    NaN
# 623  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  1997-01-01    NaN
# 624  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  1998-01-01    NaN
# 625  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  1999-01-01    0.0
# 626  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2000-01-01    1.0
# 627  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2001-01-01    2.0
# 628  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2002-01-01    2.0
# 629  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2003-01-01    2.0
# 630  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2004-01-01    2.0
# 631  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2005-01-01    2.0
# 632  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2006-01-01    2.0
# 633  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2007-01-01    NaN
# 634  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2008-01-01    NaN
# 635  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2009-01-01    NaN
# 636  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2010-01-01    NaN
# 637  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2011-01-01    NaN
# 638  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2012-01-01    NaN
# 639  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2013-01-01    NaN
# 640  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2014-01-01    NaN
# 641  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2015-01-01    NaN
# 642  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2016-01-01    NaN
# 643  PC_GDP_3Y   NSA       CA      BAL  WRL_REST      UK  2017-01-01    NaN
#
# [644 rows x 8 columns]
