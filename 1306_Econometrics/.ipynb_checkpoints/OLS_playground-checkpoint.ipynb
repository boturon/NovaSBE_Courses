# %% [markdown]
# # Dependencies

# %%
using Interact
using Gadfly
using CSV

# %%
set_default_plot_size(20cm, 20cm)

# %% [markdown]
# # Functions

# %%
function Plot_estimates(x, y, xaxis, yaxis)
    X = [ones(x) x]    
    β = inv(transpose(X)*X)*transpose(X)*y 
    SST = sum(transpose(y-mean(y))*(y-mean(y)))
    SSE = sum(transpose(X*β-mean(y))*(X*β-mean(y)))
    SSR = sum(transpose(y-X*β)*(y-X*β))
    R_squared = SSE/SST
    p = plot(
            layer(x = x, y = y, Geom.point),
            layer(x = x, y = X*β, Geom.line),
            Guide.xlabel(xaxis),
            Guide.ylabel(yaxis),
            Guide.title(join(["(β0, β1) = (", string(round(β[1], 2)), ", ", string(round(β[2], 2)), "),  R-squared: ", string(round(R_squared, 4))]))
            )
    return p
end
# Out:
# Plot_estimates (generic function with 1 method)

# %%
function Model_Regression(x_values, y_values)
    
    # Plots
    plot_linlin = Plot_estimates(x_values, y_values, "x", "y")
    plot_linlog = Plot_estimates(x_values, log.(y_values), "x", "log(y)")
    plot_loglin = Plot_estimates(log.(x_values), y_values, "log(x)", "y")
    plot_loglog = Plot_estimates(log.(x_values), log.(y_values), "log(x)", "log(y)")
    
    title(gridstack([plot_linlin plot_linlog; plot_loglin plot_loglog]), "Regression Plots")
    
end
# Out:
# Model_Regression (generic function with 1 method)

# %% [markdown]
# # Engel Example

# %%
# y
dairy = [8.87, 6.59, 11.46, 15.07, 15.6, 6.71, 10.02, 7.41, 11.52, 7.47, 6.73, 8.05, 11.03, 10.11, 18.65, 10.3, 15.3, 13.75, 11.49, 6.69, 16.2, 10.39, 13.5, 8.5, 19.77, 9.69, 7.9, 10.15, 13.82, 13.74, 4.91, 20.99, 20.06, 18.93, 13.19, 5.86, 7.43, 7.15, 9.1, 15.31]
# x
inc_per_capita = [1250, 985, 2175, 1025, 1690, 670, 1600, 940, 1730, 640, 860, 960, 1575, 1230, 2190, 1580, 2300, 1720, 850, 780, 2100, 1470, 1225, 1380, 2450, 910, 690, 1450, 2275, 1620, 740, 1125, 1335, 2875, 1680, 870, 1620, 960, 1125, 1875];

# %% [markdown]
# Problem:

# %% [markdown]
# $$ \hat{\textbf{y}} = \hat{\beta_0} + \hat{\beta_1} \cdot x = \textbf{X} \hat{\beta}$$

# %% [markdown]
# With:

# %% [markdown]
# $$ \hat{\beta} = (\textbf{X}^T \textbf{X})^{-1}\textbf{X}^T \textbf{y}$$

# %% [markdown]
# Where:

# %% [markdown]
# $$ \textbf{X} = \left[ \begin{array}{cc}
# 1 & inc per capita_{1}\\
# \ldots & \ldots  \\
# 1 & inc per capita_{n} \end{array} \right]$$

# %%
Model_Regression(inc_per_capita, dairy)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Int64},Measures.Length{:cy,Int64}},Tuple{Measures.Length{:cx,Int64},Measures.Length{:cy,Float64}}}((0cx, 0cy), (1cx, 1.0cy)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Add{Measures.Length{:h,Float64},Measures.Length{:cy,Float64}}},Tuple{Measures.Length{:cx,Int64},Measures.Length{:cy,Float64}}}((0.0cx, 0.0h + 0.1cy), (1cx, 0.9cy)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Table(Array{Compose.Context,1}[Compose.Context[Compose.Context(Measures.BoundingBox
# ...

# %% [markdown]
# <br>
