# %% [markdown]
# # Introduction to Interact.jl

# %%
using Interact
settheme!(:bulma)
# Out:
# 3-element Array{InteractBase.WidgetTheme,1}:
#  InteractBulma.Bulma()
#  InteractBulma.Bulma()
#  InteractBulma.Bulma()

# %% [markdown]
# Interact.jl provides interactive widgets for IJulia. Interaction relies on [Observables.jl](https://github.com/JuliaGizmos/Observables.jl) reactive programming package. Observables provides the type `Observable` which represent time-varying values. For example, a Slider widget can be turned into a "observable of numbers". Execute the following two cells, and then move the slider. You will see that the value of `observe(s)` changes accordingly.

# %%
s = slider(0:.1:1,label="Slider X:")
display(s)
display(observe(s));
# Out:
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "Slider X:"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.1 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# Observables.Observable{Float64}("ob_95", 0.5, Any[WebIO.SyncCallback(WebIO.Scope("knockout-component-87a42b6d-2bf0-4d8a-8ebf-b677662e20a7", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["Slider X:"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:max, 1.0),Pair{Any,Any}(:style, Dict{Any,Any}()),Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'"))),Pair{Any,Any}(:step, 0.1),Pair{Any,Any}(:className, "slider slider is-fullwidth"),Pair{Any,Any}(:min, 0.0)), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict("data-bind"=>"text: displayedvalue"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{Float64}(#= circular reference @-7 =#), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":0.5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function () {return this.value().toPrecision(6);},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-87a42b6d-2bf0-4d8a-8ebf-b677662e20a7\",\"id\":\"ob_95\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[ ...

# %% [markdown]
# Let us now inspect the types of these entities.

# %%
typeof(s)
# Out:
# InteractBase.Widget{:slider,WebIO.Scope}

# %%
display(typeof(observe(s)));
isa(observe(s), Observable)
# Out:
# Observables.Observable{Float64}
# true

# %% [markdown]
# You can have many instances of the same widget in a notebook, and they stay in sync:

# %%
s
# Out:
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "Slider X:"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.1 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))

# %% [markdown]
# ## Using Widget Signals

# %% [markdown]
# A slider is useless if you cannot do more with it than just watch its value. Thankfully we can transform one signal into another, which means we can transform the signal of values that the slider takes into, say a signal of it's squares:

# %%
xsquared = map(x -> x*x, observe(s))
# Out:
# Observables.Observable{Float64}("ob_77", 0.16000000000000003, Any[])

# %% [markdown]
# Go ahead and vary the slider to see this in action.

# %% [markdown]
# You can transform a signal into pretty much anything else. Let's use the Color package to produce different saturations of red:

# %%
using Colors
map(x -> RGB(x, 0.5, 0.5), observe(s))
# Out:
# Observables.Observable{ColorTypes.RGB{Float64}}("ob_79", RGB{Float64}(0.5,0.5,0.5), Any[])

# %% [markdown]
# You can of course use several inputs as arguments to `map` enabling you to combine many signals. Let's create a full color-picker.

# %%
r = slider(0:0.01:1, label="R")
g = slider(0:0.01:1, label="G")
b = slider(0:0.01:1, label="B")
map(display, [r,g,b]);
# Out:
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "R"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.01 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "G"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.01 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "B"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.01 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))

# %%
color = map((x, y, z) -> RGB(x, y, z), observe(r), observe(g), observe(b));
color
# Out:
# Observables.Observable{ColorTypes.RGB{Float64}}("ob_84", RGB{Float64}(0.5,0.5,0.5), Any[])

# %% [markdown]
# We can use the HTML widget to write some text you can change the color of.

# %%
map(color -> HTML(string("<div style='color:#", hex(color), "'>Hello, World!</div>")), color)
# Out:
# MethodError: no method matching start(::InteractBase.Widget{:togglebuttons,WebIO.Scope})
# Closest candidates are:
#   start(::SimpleVector) at essentials.jl:258
#   start(::Base.MethodList) at reflection.jl:560
#   start(::ExponentialBackOff) at error.jl:107
#   ...
#
# Stacktrace:
#  [1] collect(::Base.Generator{InteractBase.Widget{:togglebuttons,WebIO.Scope},##63#64}) at ./array.jl:466
#  [2] map(::Function, ::InteractBase.Widget{:togglebuttons,WebIO.Scope}) at ./abstractarray.jl:1892

# %% [markdown]
# ## The @manipulate Macro

# %% [markdown]
# The `@manipulate` macro lets you play with any expression using widgets. We could have, for example, used `@manipulate` to make a color picker along with our HTML output in one line of code:

# %%
@manipulate for r = 0:.05:1, g = 0:.05:1, b = 0:.05:1
    HTML(string("<div style='color:#", hex(RGB(r,g,b)), "'>Color me</div>"))
end
# Out:
# (div { className="interactbulma" }
#   InteractBase.Widget{:slider,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-6a48b374-6298-4f1b-8ec1-9481364138d4", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["r"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:max, 1.0),Pair{Any,Any}(:style, Dict{Any,Any}()),Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'"))),Pair{Any,Any}(:step, 0.05),Pair{Any,Any}(:className, "slider slider is-fullwidth"),Pair{Any,Any}(:min, 0.0)), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict("data-bind"=>"text: displayedvalue"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{Float64}("ob_14", 0.5, Any[WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37)), Observables.g]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":0.5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function () {return this.value().toPrecision(6);},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\", ...
#   InteractBase.Widget{:slider,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-db6e0af2-b97d-456f-b97d-230be64be22d", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["g"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:max, 1.0),Pair{Any,Any}(:style, Dict{Any,Any}()),Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'"))),Pair{Any,Any}(:step, 0.05),Pair{Any,Any}(:className, "slider slider is-fullwidth"),Pair{Any,Any}(:min, 0.0)), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict("data-bind"=>"text: displayedvalue"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{Float64}("ob_15", 0.5, Any[WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37)), Observables.g]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":0.5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function () {return this.value().toPrecision(6);},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\", ...
#   InteractBase.Widget{:slider,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-2f3734de-5bbd-4eb2-b9d2-d4e23a2f12e0", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["b"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:max, 1.0),Pair{Any,Any}(:style, Dict{Any,Any}()),Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'"))),Pair{Any,Any}(:step, 0.05),Pair{Any,Any}(:className, "slider slider is-fullwidth"),Pair{Any,Any}(:min, 0.0)), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict("data-bind"=>"text: displayedvalue"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{Float64}("ob_16", 0.5, Any[WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37)), Observables.g]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":0.5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function () {return this.value().toPrecision(6);},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\", ...
#   (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     Observables.Observable{Any}("ob_17", HTML{String}("<div style='color:#808080'>Color me</div>"), Any[])))

# %% [markdown]
# ## Signal of Widgets

# %% [markdown]
# You can in fact create signal of other widgets to update them reactively. We have seen one case with `HTML` above. Let us now create a signal of Sliders:

# %%
x = slider(0:.1:2pi, label="x")
s = slider(-1:.05:1, value=map(a->sin(2a), observe(x)), label="sin(2x)")
c = slider(-1:.05:1, value=map(a->cos(2a), observe(x)), label="cos(2x)")
map(display, [x,s,c]);
# Out:
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "x"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=6.2 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.1 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "sin(2x)"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.05 className="slider slider is-fullwidth" min=-1.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "cos(2x)"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.05 className="slider slider is-fullwidth" min=-1.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))

# %% [markdown]
# Now vary the x slider to see sin(2x) and cos(2x) get set to their appropriate values.

# %% [markdown]
# But in the above case, you cannot also use sin(2x) and cos(2x) sliders as input values (without doing tricky stuff beyond the scope of this introduction). To do this more simply, we will create a separate Input signal and pass it as an argument to map, to be the signal that the widget updates. Example:

# %%
fx = Observable(0.0) # A float input
# Out:
# Observables.Observable{Float64}("ob_22", 0.0, Any[])

# %%
x = slider(0:.1:2pi, label="x")
y = slider(-1:.05:1, value=map(sin, observe(x)), label="f(x)")
connect!(observe(y), fx)
display(x)
display(y)
display(fx);
# Out:
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "x"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=6.2 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.1 className="slider slider is-fullwidth" min=0.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# (div { className="field" }
#     (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     (div { attributes=Dict("style"=>"text-align:right;width:18%") }
#       (label { className="interactbulma " style=Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")) }
#         "f(x)"))
#     (div { attributes=Dict("style"=>"flex-grow:1; margin: 0 2%") }
#       (input { max=1.0 style=Dict{Any,Any}() attributes=Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'")) step=0.05 className="slider slider is-fullwidth" min=-1.0 }))
#     (div { attributes=Dict("style"=>"width:18%") }
#       (p { attributes=Dict("data-bind"=>"text: displayedvalue") }))))
# Observables.Observable{Float64}("ob_22", 0.0, Any[Observables.g])

# %% [markdown]
# f(x) will update as x changes. But if the user slides f(x) then the `fx` signal takes the value chosen by the user.

# %%
using Colors

timer = Observable(time())
@async while true
    sleep(0.1)
    timer[] = time()
end
    

@manipulate for color=["yellow", "cyan", "tomato"], n=3:20, t=timer
    h, w = 100, 100
    attributes = Dict(
        "fill" => color,
        "points" => join(["$(w/2*(1+sin(θ+t))),$(h/2*(1+cos(θ+t)))" for θ in 0:2π/n:2π], ' ')
    )
    dom"svg:svg[width=$w, height=$h]"(dom"svg:polygon"(attributes=attributes))
end
# Out:
# ERROR (unhandled task failure): MethodError: no method matching (::##51#53)(::String, ::Int64, ::Float64)
# The applicable method may be too new: running in world age 21917, while current world is 21920.
# Closest candidates are:
#   #51(::Any, ::Any, ::Any) at In[22]:11 (method too new to be called from this world context.)
# Stacktrace:
#  [1] (::Observables.##6#7{##51#53,Observables.Observable{Any}})(::String, ::Vararg{Any,N} where N) at /home/boturon/.julia/v0.6/Observables/src/Observables.jl:126
#  [2] (::Observables.#g#5{Observables.##6#7{##51#53,Observables.Observable{Any}},Tuple{Observables.Observable{String},Observables.Observable{Int64},Observables.Observable{Float64}}})(::Float64) at /home/boturon/.julia/v0.6/Observables/src/Observables.jl:110
#  [3] setindex!(::Observables.Observable{Float64}, ::Float64) at /home/boturon/.julia/v0.6/Observables/src/Observables.jl:72
#  [4] macro expansion at ./In[21]:4 [inlined]
#  [5] (::##41#42)() at ./task.jl:335
# (div { className="interactbulma" }
#   InteractBase.Widget{:togglebuttons,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-a47393a5-37f9-4fd5-bf9f-59a51e5b1813", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["color"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["yellow"], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict{String,Any}(Pair{String,Any}("key", 1),Pair{String,Any}("data-bind", "click: function () {index(1)}, css: {'is-primary is-selected' : index() == 1, 'button is-fullwidth' : true}")))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["cyan"], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict{String,Any}(Pair{String,Any}("key", 2),Pair{String,Any}("data-bind", "click: function () {index(2)}, css: {'is-primary is-selected' : index() == 2, 'button is-fullwidth' : true}")))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["tomato"], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict{String,Any}(Pair{String,Any}("key", 3),Pair{String,Any}("data-bind", "click: function () {index(3)}, css: {'is-primary is-selected' : index() == 3, 'button is-fullwidth' : true}")))), 1)], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "field is-grouped has-addons is-oneline is-centered")), 6)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 7), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Any,Any}(), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 13), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("index", (Observables.Observable{Int64}("ob_67", 2, Any[Observables.g, WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37))]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringifi ...
#   InteractBase.Widget{:slider,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-f822f970-5d29-48ed-90dd-ef56f1c90369", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["n"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:max, 20),Pair{Any,Any}(:style, Dict{Any,Any}()),Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'"))),Pair{Any,Any}(:step, 1),Pair{Any,Any}(:className, "slider slider is-fullwidth"),Pair{Any,Any}(:min, 3)), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict("data-bind"=>"text: displayedvalue"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{Int64}("ob_69", 11, Any[WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37)), Observables.g]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":11}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function () {return this.value();},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-comp ...
#   InteractBase.Widget{:observable,Void}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any["t"], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Observables.Observable{Float64}("ob_66", 1.53071e9, Any[Observables.g])], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Any,Any}(), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 6), nothing, Observables.Observable{Float64}("ob_66", 1.530714662993424e9, Any[Observables.g]))
#   (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     Observables.Observable{Any}("ob_70", WebIO.Node{WebIO.DOM}(WebIO.DOM(:svg, :svg), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:svg, :polygon), Any[], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("points"=>"69.2016782141078,96.16595665381426 91.11268124692265,78.45606158077634 99.97069680203636,51.71156686078962 92.96336716860674,24.423661686326454 72.31548094626736,5.256069572099737 44.58258019274317,0.2943507976010673 18.5696721704366,11.113826460730635 2.5356724347317727,34.27938904568531 1.5712632622385148,62.436135170726914 15.982637790211202,86.64449574339962 41.194274111887964,99.21848424711425 69.20167527919851,96.16595787452283","fill"=>"cyan"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("height"=>"100","width"=>"100"))), 1), Any[])))

# %%
using Plots, Colors
# Out:
# INFO: Precompiling module Plots.

# %%
timer = Observable(0.0)
@async while true
    sleep(0.1)
    timer[] = timer[]+0.1
end

@manipulate for col1 = colorant"red", col2 = colorant"blue", lw=1:0.1:10, t=timer
    x = -π:0.1:π
    plot(x, [sin.(x.+t) cos.(x.+2t)], color = [col1 col2], linewidth = lw)
end
# Out:
# ERROR (unhandled task failure): MethodError: no method matching (::##69#72)(::ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}, ::ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}, ::Float64, ::Float64)
# The applicable method may be too new: running in world age 21920, while current world is 21930.
# Closest candidates are:
#   #69(::Any, ::Any, ::Any, ::Any) at In[34]:8 (method too new to be called from this world context.)
# Stacktrace:
#  [1] (::Observables.##6#7{##69#72,Observables.Observable{Any}})(::ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}, ::Vararg{Any,N} where N) at /home/boturon/.julia/v0.6/Observables/src/Observables.jl:126
#  [2] (::Observables.#g#5{Observables.##6#7{##69#72,Observables.Observable{Any}},Tuple{Observables.Observable{ColorTypes.Color},Observables.Observable{ColorTypes.Color},Observables.Observable{Float64},Observables.Observable{Float64}}})(::Float64) at /home/boturon/.julia/v0.6/Observables/src/Observables.jl:110
#  [3] setindex!(::Observables.Observable{Float64}, ::Float64) at /home/boturon/.julia/v0.6/Observables/src/Observables.jl:72
#  [4] macro expansion at ./In[22]:6 [inlined]
#  [5] (::##49#50)() at ./task.jl:335
# (div { className="interactbulma" }
#   InteractBase.Widget{:colorpicker,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-44466c2c-93c5-489c-a226-a1256de7fddc", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["col1"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "color"),Pair{Any,Any}(Symbol("data-bind"), "value: value, valueUpdate: 'input'"))),Pair{Any,Any}(:className, "input "),Pair{Any,Any}(:style, Dict{Any,Any}())), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Any,Any}(), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{String}("ob_88", "#FF0000", Any[Observables.g, WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37))]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":\\\"#FF0000\\\"}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function (){return this.value();},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-44466c2c-93c5-489c-a226-a1256de7fddc\",\"id\":\"ob_88\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"] ...
#   InteractBase.Widget{:colorpicker,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-66355288-48f7-4ffa-b861-2ac94b2bba98", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["col2"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "color"),Pair{Any,Any}(Symbol("data-bind"), "value: value, valueUpdate: 'input'"))),Pair{Any,Any}(:className, "input "),Pair{Any,Any}(:style, Dict{Any,Any}())), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Any,Any}(), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{String}("ob_90", "#0000FF", Any[Observables.g, WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37))]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":\\\"#0000FF\\\"}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function (){return this.value();},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-66355288-48f7-4ffa-b861-2ac94b2bba98\",\"id\":\"ob_90\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"] ...
#   InteractBase.Widget{:slider,WebIO.Scope}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Scope("knockout-component-a476a9ac-1258-4cd9-aef0-6fdeeefa1c54", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["lw"], Dict{Symbol,Any}(Pair{Symbol,Any}(:className, "interactbulma "),Pair{Symbol,Any}(:style, Dict{Any,Any}(Pair{Any,Any}(:padding, "5px 10px 0px 10px")))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 2), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Any,Any}(Pair{Any,Any}(:max, 10.0),Pair{Any,Any}(:style, Dict{Any,Any}()),Pair{Any,Any}(:attributes, Dict{Any,Any}(Pair{Any,Any}(:type, "range"),Pair{Any,Any}(Symbol("data-bind"), "numericValue: value, valueUpdate: 'input'"))),Pair{Any,Any}(:step, 0.1),Pair{Any,Any}(:className, "slider slider is-fullwidth"),Pair{Any,Any}(:min, 1.0)), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(Pair{Symbol,Any}(:attributes, Dict("data-bind"=>"text: displayedvalue"))), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 7), Dict{String,Tuple{Observables.Observable,Union{Bool, Void}}}(Pair{String,Tuple{Observables.Observable,Union{Bool, Void}}}("value", (Observables.Observable{Float64}("ob_91", 5.5, Any[WebIO.SyncCallback(WebIO.Scope(#= circular reference @-7 =#), WebIO.SyncCallback(WebIO.Scope(#= circular reference @-8 =#), WebIO.#37)), Observables.g]), nothing))), Set{String}(), nothing, Any["knockout"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout.js", "knockout_punches"=>"/home/boturon/.julia/v0.6/Knockout/src/../assets/knockout_punches.js", Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "js"),Pair{String,Any}("url", "/assetserver/d59e3fb291ae1524ccdf95d613f7e5af0424385a-all.js")), Dict{String,Any}(Pair{String,Any}("name", nothing),Pair{String,Any}("type", "css"),Pair{String,Any}("url", "/assetserver/680cf50c9dc263ea696a1c7cc66fa4823cb6e0d4-main.css"))], Dict{Any,Any}(Pair{Any,Any}("_promises", Dict{Any,Any}(Pair{Any,Any}("importsLoaded", Any[WebIO.JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"value\\\":5.5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        [this[\"displayedvalue\"]=ko.computed(function () {return this.value().toPrecision(6);},this)]\n        [this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\" ...
#   InteractBase.Widget{:observable,Void}(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any["t"], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"text-align:right;width:18%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Observables.Observable{Float64}("ob_86", 1.53071e9, Any[Observables.g])], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"flex-grow:1; margin: 0 2%"))), 1), WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[], Dict{Any,Any}(), 0)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"width:18%"))), 1)], Dict{Any,Any}(Pair{Any,Any}(:attributes, Dict("style"=>"display:flex; justify-content:center; align-items:center;"))), 6), nothing, Observables.Observable{Float64}("ob_86", 1.530714806627011e9, Any[Observables.g]))
#   (div { attributes=Dict("style"=>"display:flex; justify-content:center; align-items:center;") }
#     Observables.Observable{Any}("ob_92", Plot{Plots.GRBackend() n=2}, Any[])))
