# %%
import pandas as pd
path_EU = "./../../../1104_seminar/netherlands/data/tables-of-EU-policy/converted/"

# %% [markdown]
# # A quick look at $Cd$

# %% [markdown]
# $$\widehat{Cd}_t = $$

# %%
teina023 = pd.read_csv(path_EU+"teina023.csv")
teina023["date"] = pd.to_datetime(teina023["date"])

# %%
set(teina023.na_item)
# Out:
# {'P311_S14', 'P312_S14', 'P313_S14', 'P314_S14', 'P31_S14'}

# %%
teina023[teina023.na_item == "P311_S14"]
# Out:
#            unit s_adj   na_item geotime       date  value
# 0    CLV_PCH_SM   SCA  P311_S14      AT 2015-07-01    0.9
# 1    CLV_PCH_SM   SCA  P311_S14      AT 2015-10-01    2.5
# 2    CLV_PCH_SM   SCA  P311_S14      AT 2016-01-01    3.9
# 3    CLV_PCH_SM   SCA  P311_S14      AT 2016-04-01    3.2
# 4    CLV_PCH_SM   SCA  P311_S14      AT 2016-07-01    2.5
# 5    CLV_PCH_SM   SCA  P311_S14      AT 2016-10-01    3.4
# 6    CLV_PCH_SM   SCA  P311_S14      AT 2017-01-01   -0.7
# 7    CLV_PCH_SM   SCA  P311_S14      AT 2017-04-01    0.7
# 8    CLV_PCH_SM   SCA  P311_S14      AT 2017-07-01    1.9
# 9    CLV_PCH_SM   SCA  P311_S14      AT 2017-10-01    0.2
# 10   CLV_PCH_SM   SCA  P311_S14      AT 2018-01-01    2.7
# 11   CLV_PCH_SM   SCA  P311_S14      AT 2018-04-01   -0.8
# 12   CLV_PCH_SM   SCA  P311_S14      BE 2015-07-01    0.5
# 13   CLV_PCH_SM   SCA  P311_S14      BE 2015-10-01    2.6
# 14   CLV_PCH_SM   SCA  P311_S14      BE 2016-01-01    3.5
# ...
